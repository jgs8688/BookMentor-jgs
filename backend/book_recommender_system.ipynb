# %%
import numpy as np
import pandas as pd

# %%
books = pd.read_csv('books.csv')

# %%
books.head()
# Out:
#                                        title  \
# 0                           The Hunger Games
# 1  Harry Potter and the Order of the Phoenix
# 2                      To Kill a Mockingbird
# 3                        Pride and Prejudice
# 4                                   Twilight
#
#                                       author  rating  \
# 0                            Suzanne Collins    4.33
# 1  J.K. Rowling, Mary GrandPré (Illustrator)    4.50
# 2                                 Harper Lee    4.28
# 3  Jane Austen, Anna Quindlen (Introduction)    4.26
# 4                            Stephenie Meyer    3.60
#
#                                          description  \
# 0  WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...
# 1  There is a door at the end of a silent corrido...
# 2  The unforgettable novel of a childhood in a sl...
# 3  Alternate cover edition of ISBN 9780679783268S...
# 4  About three things I was absolutely positive.\...
#
#                                               genres  numRatings  \
# 0  ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...     6376780
# 1  ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...     2507623
# 2  ['Classics', 'Fiction', 'Historical Fiction', ...     4501075
# 3  ['Classics', 'Fiction', 'Romance', 'Historical...     2998241
# 4  ['Young Adult', 'Fantasy', 'Romance', 'Vampire...     4964519
#
#                                             coverImg
# 0  https://i.gr-assets.com/images/S/compressed.ph...
# 1  https://i.gr-assets.com/images/S/compressed.ph...
# 2  https://i.gr-assets.com/images/S/compressed.ph...
# 3  https://i.gr-assets.com/images/S/compressed.ph...
# 4  https://i.gr-assets.com/images/S/compressed.ph...

# %%
print(books.shape)
# Out:
# (52478, 7)

# %%
books.isnull().sum()
# Out:
# title             0
# author            0
# rating            0
# description    1338
# genres            0
# numRatings        0
# coverImg        605
# dtype: int64

# %%
books.dropna(subset=['description'], inplace=True)

# %%
books.dropna(subset=['coverImg'], inplace=True)

# %%
books.isnull().sum()
# Out:
# title          0
# author         0
# rating         0
# description    0
# genres         0
# numRatings     0
# coverImg       0
# dtype: int64

# %%
books.shape
# Out:
# (50758, 7)

# %%
books.dtypes
# Out:
# title           object
# author          object
# rating         float64
# description     object
# genres          object
# numRatings       int64
# coverImg        object
# dtype: object

# %%
books.drop_duplicates('title')
# Out:
#                                                    title  \
# 0                                       The Hunger Games
# 1              Harry Potter and the Order of the Phoenix
# 2                                  To Kill a Mockingbird
# 3                                    Pride and Prejudice
# 4                                               Twilight
# ...                                                  ...
# 52468                                      Nameless Fate
# 52469  Heal Your Body: The Mental Causes for Physical...
# 52470                                  Attracted to Fire
# 52474                                            Anasazi
# 52477                                Daughter of Helaman
#
#                                           author  rating  \
# 0                                Suzanne Collins    4.33
# 1      J.K. Rowling, Mary GrandPré (Illustrator)    4.50
# 2                                     Harper Lee    4.28
# 3      Jane Austen, Anna Quindlen (Introduction)    4.26
# 4                                Stephenie Meyer    3.60
# ...                                          ...     ...
# 52468          Stephanie West (Goodreads Author)    3.93
# 52469                              Louise L. Hay    4.36
# 52470             DiAnn Mills (Goodreads Author)    4.14
# 52474                              Emma Michaels    4.19
# 52477            Misty Moncur (Goodreads Author)    4.02
#
#                                              description  \
# 0      WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...
# 1      There is a door at the end of a silent corrido...
# 2      The unforgettable novel of a childhood in a sl...
# 3      Alternate cover edition of ISBN 9780679783268S...
# 4      About three things I was absolutely positive.\...
# ...                                                  ...
# 52468  Harper might get an uncanny gut feeling every ...
# 52469  Heal Your Body is a fresh and easy step-by-ste...
# 52470  Special Agent Meghan Connors' dream of one day...
# 52474  'Anasazi', sequel to 'The Thirteenth Chime' by...
# 52477  Fighting in Helaman's army is Keturah's deepes...
#
#                                                   genres  numRatings  \
# 0      ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...     6376780
# 1      ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...     2507623
# 2      ['Classics', 'Fiction', 'Historical Fiction', ...     4501075
# 3      ['Classics', 'Fiction', 'Romance', 'Historical...     2998241
# 4      ['Young Adult', 'Fantasy', 'Romance', 'Vampire...     4964519
# ...                                                  ...         ...
# 52468  ['Aliens', 'Science Fiction', 'Romance', 'Erot...         508
# 52469  ['Self Help', 'Health', 'Nonfiction', 'Spiritu...       14868
# 52470  ['Christian Fiction', 'Christian', 'Suspense',...        2143
# 52474                         ['Mystery', 'Young Adult']          37
# 52477  ['Lds Fiction', 'Historical Fiction', 'Young A...         246
#
#                                                 coverImg
# 0      https://i.gr-assets.com/images/S/compressed.ph...
# 1      https://i.gr-assets.com/images/S/compressed.ph...
# 2      https://i.gr-assets.com/images/S/compressed.ph...
# 3      https://i.gr-assets.com/images/S/compressed.ph...
# 4      https://i.gr-assets.com/images/S/compressed.ph...
# ...                                                  ...
# 52468  https://i.gr-assets.com/images/S/compressed.ph...
# 52469  https://i.gr-assets.com/images/S/compressed.ph...
# 52470  https://i.gr-assets.com/images/S/compressed.ph...
# 52474  https://i.gr-assets.com/images/S/compressed.ph...
# 52477  https://i.gr-assets.com/images/S/compressed.ph...
#
# [48268 rows x 7 columns]

# %% [markdown]
# ## Popularity Based Recommender System

# %%
popular_df = books[books['numRatings'] >= 500000]
popular_df
# Out:
#                                                   title  \
# 0                                      The Hunger Games
# 1             Harry Potter and the Order of the Phoenix
# 2                                 To Kill a Mockingbird
# 3                                   Pride and Prejudice
# 4                                              Twilight
# ...                                                 ...
# 1742                                 The Silent Patient
# 1970                               The Husband's Secret
# 2081                                           Becoming
# 2341                            Little Fires Everywhere
# 2741  The Subtle Art of Not Giving a F*ck: A Counter...
#
#                                          author  rating  \
# 0                               Suzanne Collins    4.33
# 1     J.K. Rowling, Mary GrandPré (Illustrator)    4.50
# 2                                    Harper Lee    4.28
# 3     Jane Austen, Anna Quindlen (Introduction)    4.26
# 4                               Stephenie Meyer    3.60
# ...                                         ...     ...
# 1742        Alex Michaelides (Goodreads Author)    4.09
# 1970          Liane Moriarty (Goodreads Author)    3.94
# 2081          Michelle Obama (Goodreads Author)    4.53
# 2341              Celeste Ng (Goodreads Author)    4.10
# 2741             Mark Manson (Goodreads Author)    3.94
#
#                                             description  \
# 0     WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...
# 1     There is a door at the end of a silent corrido...
# 2     The unforgettable novel of a childhood in a sl...
# 3     Alternate cover edition of ISBN 9780679783268S...
# 4     About three things I was absolutely positive.\...
# ...                                                 ...
# 1742  Alicia Berenson’s life is seemingly perfect. A...
# 1970  At the heart of The Husband’s Secret is a lett...
# 2081  In a life filled with meaning and accomplishme...
# 2341  From the bestselling author of Everything I Ne...
# 2741  Alternate cover edition of ISBN 9780062457738I...
#
#                                                  genres  numRatings  \
# 0     ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...     6376780
# 1     ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...     2507623
# 2     ['Classics', 'Fiction', 'Historical Fiction', ...     4501075
# 3     ['Classics', 'Fiction', 'Romance', 'Historical...     2998241
# 4     ['Young Adult', 'Fantasy', 'Romance', 'Vampire...     4964519
# ...                                                 ...         ...
# 1742  ['Mystery', 'Thriller', 'Fiction', 'Mystery Th...      507237
# 1970  ['Fiction', 'Mystery', 'Chick Lit', 'Contempor...      532210
# 2081  ['Nonfiction', 'Memoir', 'Biography', 'Audiobo...      564220
# 2341  ['Fiction', 'Contemporary', 'Audiobook', 'Adul...      712854
# 2741  ['Nonfiction', 'Self Help', 'Psychology', 'Aud...      529645
#
#                                                coverImg
# 0     https://i.gr-assets.com/images/S/compressed.ph...
# 1     https://i.gr-assets.com/images/S/compressed.ph...
# 2     https://i.gr-assets.com/images/S/compressed.ph...
# 3     https://i.gr-assets.com/images/S/compressed.ph...
# 4     https://i.gr-assets.com/images/S/compressed.ph...
# ...                                                 ...
# 1742  https://i.gr-assets.com/images/S/compressed.ph...
# 1970  https://i.gr-assets.com/images/S/compressed.ph...
# 2081  https://i.gr-assets.com/images/S/compressed.ph...
# 2341  https://i.gr-assets.com/images/S/compressed.ph...
# 2741  https://i.gr-assets.com/images/S/compressed.ph...
#
# [234 rows x 7 columns]

# %%
# Sort by Avg_Rating descending and pick top 50
popular_df = popular_df.sort_values(by='rating', ascending=False).head(50)

# %%
# Keep only desired columns for display
popular_df = popular_df[['title', 'author', 'rating','numRatings', 'genres', 'coverImg',]]

# %%
# Final preview
popular_df.head()
# Out:
#                                         title  \
# 71       Harry Potter and the Deathly Hallows
# 93   Harry Potter and the Prisoner of Azkaban
# 105    Harry Potter and the Half-Blood Prince
# 709                           The Nightingale
# 103       Harry Potter and the Goblet of Fire
#
#                                         author  rating  numRatings  \
# 71                                J.K. Rowling    4.62     2811637
# 93   J.K. Rowling, Mary GrandPré (Illustrator)    4.57     2806471
# 105                               J.K. Rowling    4.57     2437658
# 709          Kristin Hannah (Goodreads Author)    4.57      697799
# 103  J.K. Rowling, Mary GrandPré (Illustrator)    4.56     2594622
#
#                                                 genres  \
# 71   ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...
# 93   ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...
# 105  ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...
# 709  ['Historical Fiction', 'Fiction', 'Historical'...
# 103  ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...
#
#                                               coverImg
# 71   https://i.gr-assets.com/images/S/compressed.ph...
# 93   https://i.gr-assets.com/images/S/compressed.ph...
# 105  https://i.gr-assets.com/images/S/compressed.ph...
# 709  https://i.gr-assets.com/images/S/compressed.ph...
# 103  https://i.gr-assets.com/images/S/compressed.ph...

# %%
popular_df['coverImg'].iloc[0]
# Out:
# 'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1474171184l/136251._SY475_.jpg'

# %% [markdown]
# ## Content Filtering Based Recommender System

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pickle
# books.columns

# %%
books['content'] = books['title'] + ' ' + books['author'] + ' ' + books['genres']

# %%
new_books = books[books['numRatings'] >= 10000]

# %%
new_books.shape
books = new_books

# %%
tfidf = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf.fit_transform(books['content'])

# %%
similarity_scores = cosine_similarity(tfidf_matrix)

# %%
pickle.dump(popular_df,open('popular.pkl','wb'))
pickle.dump(books, open('books.pkl', 'wb'))
pickle.dump(similarity_scores, open('similarity_scores.pkl', 'wb'))

# %%
books = pickle.load(open('books.pkl', 'rb'))
similarity_scores = pickle.load(open('similarity_scores.pkl', 'rb'))

def recommend(book_name):
    if book_name not in books['title'].values:
        return f"❌ Book '{book_name}' not found."

    index = books[books['title'] == book_name].index[0]

    similar_items = sorted(list(enumerate(similarity_scores[index])), key=lambda x: x[1], reverse=True)[1:6]

    data = []
    for i in similar_items:
        item = []
        book_row = books.iloc[i[0]]
        item.append(book_row['title'])
        item.append(book_row['author'])
        item.append(book_row['coverImg'])  # use 'coverImg' instead of 'URL'
        data.append(item)

    return data

# %%
recommend('Animal Farm')
# Out:
# [['Animal Farm / 1984',
#   'George Orwell, Christopher Hitchens (Introduction)',
#   'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1327959366l/5472.jpg'],
#  ['1984',
#   'George Orwell',
#   'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1532714506l/40961427._SX318_.jpg'],
#  ['Anthem',
#   'Ayn Rand',
#   'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1388190459l/667.jpg'],
#  ['The Natural',
#   'Bernard Malamud, Kevin Baker (Goodreads Author) (Introduction)',
#   'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1417605559l/685.jpg'],
#  ['The Pearl',
#   'John Steinbeck',
#   'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1437234939l/5308.jpg']]
